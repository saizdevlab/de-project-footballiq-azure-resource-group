# %%
# %sql
CREATE CATALOG IF NOT EXISTS football_catalog COMMENT 'FootballIQ Portfolio Project';

# %%
# %sql
-- Create the three medallion schemas
CREATE SCHEMA IF NOT EXISTS football_catalog.bronze COMMENT 'Raw ingested data, append-only, string types';
CREATE SCHEMA IF NOT EXISTS football_catalog.silver COMMENT 'Cleaned, typed, validated dims and facts';
CREATE SCHEMA IF NOT EXISTS football_catalog.gold   COMMENT 'Business-ready aggregations and KPIs';
